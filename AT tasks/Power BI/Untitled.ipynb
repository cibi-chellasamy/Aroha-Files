# %%
import pandas as pd

# %%
df = pd.read_excel('Fictitious Customer Data Set (2).xlsx')

# %%
df
# Out:
#      Fictitious Customer Data Set             Unnamed: 1 Unnamed: 2  \
# 0                             NaN                    NaN        NaN
# 1                             NaN                    NaN        NaN
# 2                     Customer ID                Address       City
# 3                           18453    7736 Abbott Hill Rd     Boston
# 4                           17564         51 Steiner Ave    Buffalo
# ...                           ...                    ...        ...
# 2000                        40841  8890 S Greenbriar Ter     Boston
# 2001                        35588        50 Creekwood Dr  Lancaster
# 2002                        19120     3184 Clearview Way    Buffalo
# 2003                          NaN                    NaN        NaN
# 2004                          NaN                    NaN        NaN
#
#      Unnamed: 3 Unnamed: 4     Unnamed: 5  \
# 0           NaN        NaN            NaN
# 1           NaN        NaN            NaN
# ...

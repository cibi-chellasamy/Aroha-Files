# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df_cc = pd.read_csv('Call_center.csv')
df_ic = pd.read_csv('Instore_customer.csv')
df_wc = pd.read_excel('Web_customer.xlsx')

# %%
df_cc.head(2)
# Out:
#    Cust_Id         Cust_name       City      Rep_name        Phone
# 0     1001   Samantha Greene    chennai  Aarav Sharma  98765 43210
# 1     1002  Marcus Rodriguez  bangalore           NaN          NaN

# %%
df_ic.head(2)
# Out:
#    Cust_Id    Cust_name       City              Store_name
# 0     2001  Emily Chang  bangalore  Sparkle Haven Boutique
# 1     2002   Mia Rivera    chennai    Timberland Treasures

# %%
df_wc.head(2)
# Out:
#    Cust_Id        Cust_name       City                     Email    Status
# 0     3001  Benjamin Carter  bangalore  BenjaminCarter@gmail.com  accepted
# 1     3002       Maya Patel     mumbai       MayaPatel@gmail.com  accepted

# %%
df_cc['Source'] = 'call_center'
df_ic['Source'] = 'in_store'
df_wc['Source'] = 'web'

# %%
df_rejectedcc =df_cc [df_cc.isna().any(axis = 1)]

# %%
df[]

# %%
df_rejectedcc['Reason'] = ''

if 'Phone' in df_rejectedcc.columns:
    df_rejectedcc.loc[df_rejectedcc['Phone'].isnull(), 'Reason'] = 'Phone number missing'

if 'Rep_name' in df_rejectedcc.columns:
    df_rejectedcc.loc[df_rejectedcc['Rep_name'].isnull(), 'Reason'] = 'Representative name missing'

# %%
df_rejectedcc
# Out:
#    Cust_Id         Cust_name       City     Rep_name        Phone  \
# 1     1002  Marcus Rodriguez  bangalore          NaN          NaN
# 3     1004      Xavier Patel    chennai          NaN  65432 10987
# 4     1005   Olivia Thompson  bangalore  Rohan Mehta          NaN
# 7     1008     Jackson Brown     mumbai          NaN  21098 76543
#
#         Source                       Reason
# 1  call_center  Representative name missing
# 3  call_center  Representative name missing
# 4  call_center         Phone number missing
# 7  call_center  Representative name missing

# %%
df_ic.isnull().sum()
# Out:
# Cust_Id       0
# Cust_name     1
# City          1
# Store_name    2
# Source        0
# dtype: int64

# %%
df_rejectedic =df_ic [df_ic.isna().any(axis = 1)]

# %%
df_rejectedic
# Out:
#    Cust_Id     Cust_name       City              Store_name    Source
# 2     2003  Liam Johnson    chennai                     NaN  in_store
# 5     2006  Sofia Garcia        NaN         Blissful Bazaar  in_store
# 7     2008           NaN  bangalore  Urban Oasis Outfitters  in_store
# 8     2009   Ethan Brown     mumbai                     NaN  in_store

# %%
df_rejectedic['Reason'] = ''

if 'Cust_name' in df_rejectedic.columns:
    df_rejectedic.loc[df_rejectedic['Cust_name'].isnull(), 'Reason'] = 'Customer name missing'

if 'City' in df_rejectedic.columns:
    df_rejectedic.loc[df_rejectedic['City'].isnull(), 'Reason'] = 'City missing'
    
if 'Store_name' in df_rejectedic.columns:
    df_rejectedic.loc[df_rejectedic['Store_name'].isnull(), 'Reason'] = 'Store name missing'

# %%
df_rejectedic
# Out:
#    Cust_Id     Cust_name       City              Store_name    Source  \
# 2     2003  Liam Johnson    chennai                     NaN  in_store
# 5     2006  Sofia Garcia        NaN         Blissful Bazaar  in_store
# 7     2008           NaN  bangalore  Urban Oasis Outfitters  in_store
# 8     2009   Ethan Brown     mumbai                     NaN  in_store
#
#                   Reason
# 2     Store name missing
# 5           City missing
# 7  Customer name missing
# 8     Store name missing

# %%
df_wc
# Out:
#    Cust_Id         Cust_name       City                      Email    Status  \
# 0     3001   Benjamin Carter  bangalore   BenjaminCarter@gmail.com  accepted
# 1     3002        Maya Patel     mumbai        MayaPatel@gmail.com  accepted
# 2     3003    Logan Thompson    chennai    LoganThompsongemail.com   blocked
# 3     3004         Aria Khan  bangalore          AriaKhangmail.com   blocked
# 4     3005       Emily Chang  bangalore       EmilyChang@gmail.com  accepted
# 5     3006        Mia Rivera    chennai        MiaRivera@gmail.com   blocked
# 6     3007   Elijah Williams    chennai    ElijahWilliamsgmail.com  accepted
# 7     3008      Mia Martinez     mumbai      MiaMartinez@gmail.com  accepted
# 8     3009  Oliver Rodriguez  bangalore  OliverRodriguez@gmail.com   blocked
# 9     3010        Zoey Gupta     mumbai         ZoeyGuptaemail.com   blocked
#
#   Source
# 0    web
# 1    web
# 2    web
# 3    web
# 4    web
# 5    web
# 6    web
# 7    web
# 8    web
# 9    web

# %%
df_rejectedwc = pd.DataFrame()

# %%
for index, row in df_wc.iterrows():
    if '@' not in row['Email']:
        df_rejectedwc = df_rejectedwc.append(row)

# %%
df_rejectedwc
# Out:
#    Cust_Id        Cust_name       City                    Email    Status  \
# 2     3003   Logan Thompson    chennai  LoganThompsongemail.com   blocked
# 3     3004        Aria Khan  bangalore        AriaKhangmail.com   blocked
# 6     3007  Elijah Williams    chennai  ElijahWilliamsgmail.com  accepted
# 9     3010       Zoey Gupta     mumbai       ZoeyGuptaemail.com   blocked
#
#   Source
# 2    web
# 3    web
# 6    web
# 9    web

# %%
df_rejectedic
# Out:
#    Cust_Id     Cust_name       City              Store_name    Source  \
# 2     2003  Liam Johnson    chennai                     NaN  in_store
# 5     2006  Sofia Garcia        NaN         Blissful Bazaar  in_store
# 7     2008           NaN  bangalore  Urban Oasis Outfitters  in_store
# 8     2009   Ethan Brown     mumbai                     NaN  in_store
#
#                   Reason
# 2     Store name missing
# 5           City missing
# 7  Customer name missing
# 8     Store name missing

# %%
df_rejectedcc
# Out:
#    Cust_Id         Cust_name       City     Rep_name        Phone  \
# 1     1002  Marcus Rodriguez  bangalore          NaN          NaN
# 3     1004      Xavier Patel    chennai          NaN  65432 10987
# 4     1005   Olivia Thompson  bangalore  Rohan Mehta          NaN
# 7     1008     Jackson Brown     mumbai          NaN  21098 76543
#
#         Source                       Reason
# 1  call_center  Representative name missing
# 3  call_center  Representative name missing
# 4  call_center         Phone number missing
# 7  call_center  Representative name missing

# %%
df_rejectedwc['Reason'] = 'Email mismatch'

# %%
df_merged = pd.concat([df_rejectedcc, df_rejectedic, df_rejectedwc], ignore_index=True)

# %%
df_merged
# Out:
#     Cust_Id         Cust_name       City     Rep_name        Phone  \
# 0      1002  Marcus Rodriguez  bangalore          NaN          NaN
# 1      1004      Xavier Patel    chennai          NaN  65432 10987
# 2      1005   Olivia Thompson  bangalore  Rohan Mehta          NaN
# 3      1008     Jackson Brown     mumbai          NaN  21098 76543
# 4      2003      Liam Johnson    chennai          NaN          NaN
# 5      2006      Sofia Garcia        NaN          NaN          NaN
# 6      2008               NaN  bangalore          NaN          NaN
# 7      2009       Ethan Brown     mumbai          NaN          NaN
# 8      3003    Logan Thompson    chennai          NaN          NaN
# 9      3004         Aria Khan  bangalore          NaN          NaN
# 10     3007   Elijah Williams    chennai          NaN          NaN
# 11     3010        Zoey Gupta     mumbai          NaN          NaN
#
#          Source                       Reason              Store_name  \
# 0   call_center  Representative name missing                     NaN
# 1   call_center  Representative name missing                     NaN
# 2   call_center         Phone number missing                     NaN
# 3   call_center  Representative name missing                     NaN
# 4      in_store           Store name missing                     NaN
# 5      in_store                 City missing         Blissful Bazaar
# 6      in_store        Customer name missing  Urban Oasis Outfitters
# 7      in_store           Store name missing                     NaN
# 8           web               Email mismatch                     NaN
# 9           web               Email mismatch                     NaN
# 10          web               Email mismatch                     NaN
# 11          web               Email mismatch                     NaN
#
#                       Email    Status
# 0                       NaN       NaN
# 1                       NaN       NaN
# 2                       NaN       NaN
# 3                       NaN       NaN
# 4                       NaN       NaN
# 5                       NaN       NaN
# 6                       NaN       NaN
# 7                       NaN       NaN
# 8   LoganThompsongemail.com   blocked
# 9         AriaKhangmail.com   blocked
# 10  ElijahWilliamsgmail.com  accepted
# 11       ZoeyGuptaemail.com   blocked

# %%
df_merged = df_merged.loc[:, ~df_merged.columns.duplicated()]

# %%
df_merged
# Out:
#     Cust_Id         Cust_name       City     Rep_name        Phone  \
# 0      1002  Marcus Rodriguez  bangalore          NaN          NaN
# 1      1004      Xavier Patel    chennai          NaN  65432 10987
# 2      1005   Olivia Thompson  bangalore  Rohan Mehta          NaN
# 3      1008     Jackson Brown     mumbai          NaN  21098 76543
# 4      2003      Liam Johnson    chennai          NaN          NaN
# 5      2006      Sofia Garcia        NaN          NaN          NaN
# 6      2008               NaN  bangalore          NaN          NaN
# 7      2009       Ethan Brown     mumbai          NaN          NaN
# 8      3003    Logan Thompson    chennai          NaN          NaN
# 9      3004         Aria Khan  bangalore          NaN          NaN
# 10     3007   Elijah Williams    chennai          NaN          NaN
# 11     3010        Zoey Gupta     mumbai          NaN          NaN
#
#          Source                       Reason              Store_name  \
# 0   call_center  Representative name missing                     NaN
# 1   call_center  Representative name missing                     NaN
# 2   call_center         Phone number missing                     NaN
# 3   call_center  Representative name missing                     NaN
# 4      in_store           Store name missing                     NaN
# 5      in_store                 City missing         Blissful Bazaar
# 6      in_store        Customer name missing  Urban Oasis Outfitters
# 7      in_store           Store name missing                     NaN
# 8           web               Email mismatch                     NaN
# 9           web               Email mismatch                     NaN
# 10          web               Email mismatch                     NaN
# 11          web               Email mismatch                     NaN
#
#                       Email    Status
# 0                       NaN       NaN
# 1                       NaN       NaN
# 2                       NaN       NaN
# 3                       NaN       NaN
# 4                       NaN       NaN
# 5                       NaN       NaN
# 6                       NaN       NaN
# 7                       NaN       NaN
# 8   LoganThompsongemail.com   blocked
# 9         AriaKhangmail.com   blocked
# 10  ElijahWilliamsgmail.com  accepted
# 11       ZoeyGuptaemail.com   blocked

# %%
df_rejected = df_merged[['Cust_Id','Source','Reason']]

# %%
df_wc.dropna(inplace=True)
df_ic.dropna(inplace=True)
df_cc.dropna(inplace=True)

# %%
merged = pd.merge(df_wc, df_rejectedwc, how='outer', indicator=True)

# %%
dfw = merged[merged['_merge'] == 'left_only'].drop(columns='_merge')

# %%
dfw
# Out:
#    Cust_Id         Cust_name       City                      Email    Status  \
# 0     3001   Benjamin Carter  bangalore   BenjaminCarter@gmail.com  accepted
# 1     3002        Maya Patel     mumbai        MayaPatel@gmail.com  accepted
# 4     3005       Emily Chang  bangalore       EmilyChang@gmail.com  accepted
# 5     3006        Mia Rivera    chennai        MiaRivera@gmail.com   blocked
# 7     3008      Mia Martinez     mumbai      MiaMartinez@gmail.com  accepted
# 8     3009  Oliver Rodriguez  bangalore  OliverRodriguez@gmail.com   blocked
#
#   Source Reason
# 0    web    NaN
# 1    web    NaN
# 4    web    NaN
# 5    web    NaN
# 7    web    NaN
# 8    web    NaN

# %%
df_cc
# Out:
#    Cust_Id        Cust_name       City         Rep_name        Phone  \
# 0     1001  Samantha Greene    chennai     Aarav Sharma  98765 43210
# 2     1003      Emily Chang  bangalore      Arjun Desai  76543 21098
# 5     1006     Ethan Carter     mumbai       Maya Gupta  43210 98765
# 6     1007  Isabella Nguyen    chennai  Kunal Singhania  32109 87654
# 8     1009       Mia Rivera    chennai   Virat Malhotra  10987 65432
# 9     1010   Caleb Sullivan     mumbai       Diya Verma  09876 54321
#
#         Source
# 0  call_center
# 2  call_center
# 5  call_center
# 6  call_center
# 8  call_center
# 9  call_center

# %%
df_ic
# Out:
#    Cust_Id       Cust_name       City              Store_name    Source
# 0     2001     Emily Chang  bangalore  Sparkle Haven Boutique  in_store
# 1     2002      Mia Rivera    chennai    Timberland Treasures  in_store
# 3     2004     Aisha Patel    chennai  Moonlit Marvels Market  in_store
# 4     2005   Noah Williams  bangalore        Rustic Charm Co.  in_store
# 6     2007  Lucas Thompson     mumbai    Serenity Street Shop  in_store
# 9     2010       Mia Lopez    chennai     Harmony Haven Store  in_store

# %%
dfw.drop('Reason',axis=1,inplace=True)

# %%
dfw
# Out:
#    Cust_Id         Cust_name       City                      Email    Status  \
# 0     3001   Benjamin Carter  bangalore   BenjaminCarter@gmail.com  accepted
# 1     3002        Maya Patel     mumbai        MayaPatel@gmail.com  accepted
# 4     3005       Emily Chang  bangalore       EmilyChang@gmail.com  accepted
# 5     3006        Mia Rivera    chennai        MiaRivera@gmail.com   blocked
# 7     3008      Mia Martinez     mumbai      MiaMartinez@gmail.com  accepted
# 8     3009  Oliver Rodriguez  bangalore  OliverRodriguez@gmail.com   blocked
#
#   Source
# 0    web
# 1    web
# 4    web
# 5    web
# 7    web
# 8    web

# %%
df_master = pd.concat([df_ic,df_cc,dfw],ignore_index=True)

# %%
df_master
# Out:
#     Cust_Id         Cust_name       City              Store_name       Source  \
# 0      2001       Emily Chang  bangalore  Sparkle Haven Boutique     in_store
# 1      2002        Mia Rivera    chennai    Timberland Treasures     in_store
# 2      2004       Aisha Patel    chennai  Moonlit Marvels Market     in_store
# 3      2005     Noah Williams  bangalore        Rustic Charm Co.     in_store
# 4      2007    Lucas Thompson     mumbai    Serenity Street Shop     in_store
# 5      2010         Mia Lopez    chennai     Harmony Haven Store     in_store
# 6      1001   Samantha Greene    chennai                     NaN  call_center
# 7      1003       Emily Chang  bangalore                     NaN  call_center
# 8      1006      Ethan Carter     mumbai                     NaN  call_center
# 9      1007   Isabella Nguyen    chennai                     NaN  call_center
# 10     1009        Mia Rivera    chennai                     NaN  call_center
# 11     1010    Caleb Sullivan     mumbai                     NaN  call_center
# 12     3001   Benjamin Carter  bangalore                     NaN          web
# 13     3002        Maya Patel     mumbai                     NaN          web
# 14     3005       Emily Chang  bangalore                     NaN          web
# 15     3006        Mia Rivera    chennai                     NaN          web
# 16     3008      Mia Martinez     mumbai                     NaN          web
# 17     3009  Oliver Rodriguez  bangalore                     NaN          web
#
#            Rep_name        Phone                      Email    Status
# 0               NaN          NaN                        NaN       NaN
# 1               NaN          NaN                        NaN       NaN
# 2               NaN          NaN                        NaN       NaN
# 3               NaN          NaN                        NaN       NaN
# 4               NaN          NaN                        NaN       NaN
# 5               NaN          NaN                        NaN       NaN
# 6      Aarav Sharma  98765 43210                        NaN       NaN
# 7       Arjun Desai  76543 21098                        NaN       NaN
# 8        Maya Gupta  43210 98765                        NaN       NaN
# 9   Kunal Singhania  32109 87654                        NaN       NaN
# 10   Virat Malhotra  10987 65432                        NaN       NaN
# 11       Diya Verma  09876 54321                        NaN       NaN
# 12              NaN          NaN   BenjaminCarter@gmail.com  accepted
# 13              NaN          NaN        MayaPatel@gmail.com  accepted
# 14              NaN          NaN       EmilyChang@gmail.com  accepted
# 15              NaN          NaN        MiaRivera@gmail.com   blocked
# 16              NaN          NaN      MiaMartinez@gmail.com  accepted
# 17              NaN          NaN  OliverRodriguez@gmail.com   blocked

# %%
df_master = df_master.drop_duplicates(subset=['Cust_Id'], keep='first')

# %%
df_master
# Out:
#     Cust_Id         Cust_name       City              Store_name       Source  \
# 0      2001       Emily Chang  bangalore  Sparkle Haven Boutique     in_store
# 1      2002        Mia Rivera    chennai    Timberland Treasures     in_store
# 2      2004       Aisha Patel    chennai  Moonlit Marvels Market     in_store
# 3      2005     Noah Williams  bangalore        Rustic Charm Co.     in_store
# 4      2007    Lucas Thompson     mumbai    Serenity Street Shop     in_store
# 5      2010         Mia Lopez    chennai     Harmony Haven Store     in_store
# 6      1001   Samantha Greene    chennai                     NaN  call_center
# 7      1003       Emily Chang  bangalore                     NaN  call_center
# 8      1006      Ethan Carter     mumbai                     NaN  call_center
# 9      1007   Isabella Nguyen    chennai                     NaN  call_center
# 10     1009        Mia Rivera    chennai                     NaN  call_center
# 11     1010    Caleb Sullivan     mumbai                     NaN  call_center
# 12     3001   Benjamin Carter  bangalore                     NaN          web
# 13     3002        Maya Patel     mumbai                     NaN          web
# 14     3005       Emily Chang  bangalore                     NaN          web
# 15     3006        Mia Rivera    chennai                     NaN          web
# 16     3008      Mia Martinez     mumbai                     NaN          web
# 17     3009  Oliver Rodriguez  bangalore                     NaN          web
#
#            Rep_name        Phone                      Email    Status
# 0               NaN          NaN                        NaN       NaN
# 1               NaN          NaN                        NaN       NaN
# 2               NaN          NaN                        NaN       NaN
# 3               NaN          NaN                        NaN       NaN
# 4               NaN          NaN                        NaN       NaN
# 5               NaN          NaN                        NaN       NaN
# 6      Aarav Sharma  98765 43210                        NaN       NaN
# 7       Arjun Desai  76543 21098                        NaN       NaN
# 8        Maya Gupta  43210 98765                        NaN       NaN
# 9   Kunal Singhania  32109 87654                        NaN       NaN
# 10   Virat Malhotra  10987 65432                        NaN       NaN
# 11       Diya Verma  09876 54321                        NaN       NaN
# 12              NaN          NaN   BenjaminCarter@gmail.com  accepted
# 13              NaN          NaN        MayaPatel@gmail.com  accepted
# 14              NaN          NaN       EmilyChang@gmail.com  accepted
# 15              NaN          NaN        MiaRivera@gmail.com   blocked
# 16              NaN          NaN      MiaMartinez@gmail.com  accepted
# 17              NaN          NaN  OliverRodriguez@gmail.com   blocked

# %%
df_master = df_master.drop_duplicates(subset=['Cust_name'])

# %%
df_master.rename(columns = {'Cust_Id':'Source_Id'}, inplace = True)

# %%
df_master['Cust_Id'] = range(100,100+len(df_master))

# %%
file_path = "Customer master xl.xlsx"
df_master.to_excel(file_path, index=False)

# %%
file_path = "Rejected Customers.xlsx"
df_rejected.to_excel(file_path, index=False)

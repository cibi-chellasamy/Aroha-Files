# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('ilearn.xlsx')

# %%
df.head(5)
# Out:
#     id first_name last_name          last_login  \
# 0  119     Shruti       NaN 2018-02-09 12:37:00
# 1  119     Shruti       NaN 2018-02-09 12:37:00
# 2  119     Shruti       NaN 2018-02-09 12:37:00
# 3  119     Shruti       NaN 2018-02-09 12:37:00
# 4  119     Shruti       NaN 2018-02-09 12:37:00
#
#                                                 path           timestamp
# 0                                                  / 2017-10-06 09:09:00
# 1  /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-06 09:09:00
# 2  /courses/informatica/rank-transforamtion-infor... 2017-10-06 09:09:00
# 3                                                  / 2017-10-06 10:25:00
# 4                                                  / 2017-10-06 10:25:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2162 entries, 0 to 2161
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          2162 non-null   int64
#  1   first_name  2162 non-null   object
#  2   last_name   1991 non-null   object
#  3   last_login  2162 non-null   datetime64[ns]
#  4   path        2162 non-null   object
#  5   timestamp   2162 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 101.5+ KB

# %%
df_il = pd.DataFrame()

# %%
df_il['access_id'] = df['id']

# %%
df_il['access_date'] = df['timestamp'].dt.strftime('%d-%m-%Y')

# %%
df_il
# Out:
#       access_id access_date
# 0           119  06-10-2017
# 1           119  06-10-2017
# 2           119  06-10-2017
# 3           119  06-10-2017
# 4           119  06-10-2017
# ...         ...         ...
# 2157        386  27-05-2018
# 2158        386  27-05-2018
# 2159        386  27-05-2018
# 2160        386  27-05-2018
# 2161        386  27-05-2018
#
# [2162 rows x 2 columns]

# %%
proper_log = []
imporper_log = []

for i in df['path']:
    if len(i)>1:
        proper_log.append(i)
    if len(i) ==1:
        imporper_log.append(i)

# %%
proper_log = df[df['path'].isin(proper_log)].reset_index(drop = True)

# %%
df_il['path'] = proper_log['path']

# %%
df_il.dropna(inplace=True)

# %%
df_logrej = pd.DataFrame()

# %%
df_logrej = df[df['path'].isin(imporper_log)].reset_index(drop = True)

# %%
df_il[['empty', 'empty2', 'Course', 'Chapter', 'empty3']] = pd.DataFrame(df_il['path'].str.split('/').tolist())

# %%
df_il[['access_id','access_date','Course','Chapter']]
# Out:
#       access_id access_date        Course                              Chapter
# 0           119  06-10-2017    oracle-sql   introduction-to-sql-oracle-sql-102
# 1           119  06-10-2017   informatica  rank-transforamtion-informatica-405
# 2           119  06-10-2017    oracle-sql   introduction-to-sql-oracle-sql-102
# 3           119  06-10-2017    oracle-sql
# 4           119  06-10-2017  oracle-plsql
# ...         ...         ...           ...                                  ...
# 1735        360  02-05-2018         rdbms                  ef-codds-rules-file
# 1736        360  02-05-2018         rdbms                  ef-codds-rules-file
# 1737        360  15-05-2018         rdbms
# 1738        360  15-05-2018         rdbms  what-is-a-transaction-file-rdbms-40
# 1739        360  15-05-2018         rdbms  what-is-a-transaction-file-rdbms-40
#
# [1740 rows x 4 columns]

# %%
df_main = df_il[['access_id','access_date','Course','Chapter']]

# %%
df_main = df_main[df_main['Chapter']!='']

# %%
df_main = df_main.reset_index(drop=True)

# %%
dfe = pd.read_excel('Employee xl.xlsx')

# %%
df_main['first_name'] = df['first_name']

# %%
df_main = df_main.merge(dfe[['first_name', 'Employee_id']], on='first_name', how='left')

# %%
df_main = df_main.drop(['first_name','access_id'],axis=1)

# %%
df_main['Access_id'] = range(1000,1000+len(df_main['Employee_id']))

# %%
df_main.reset_index(drop=True)
# Out:
#      access_date       Course                                      Chapter  \
# 0     06-10-2017   oracle-sql           introduction-to-sql-oracle-sql-102
# 1     06-10-2017  informatica          rank-transforamtion-informatica-405
# 2     06-10-2017   oracle-sql           introduction-to-sql-oracle-sql-102
# 3     11-10-2017  informatica  introduction-to-informatica-informatica-392
# 4     11-10-2017  informatica           working-with-files-informatica-394
# ...          ...          ...                                          ...
# 1108  10-05-2018        rdbms        primary-key-foreign-key-file-rdbms-38
# 1109  02-05-2018        rdbms                          ef-codds-rules-file
# 1110  02-05-2018        rdbms                          ef-codds-rules-file
# 1111  15-05-2018        rdbms          what-is-a-transaction-file-rdbms-40
# 1112  15-05-2018        rdbms          what-is-a-transaction-file-rdbms-40
#
#       Employee_id  Access_id
# 0             100       1000
# 1             100       1001
# 2             100       1002
# 3             100       1003
# 4             100       1004
# ...           ...        ...
# 1108          116       2108
# 1109          116       2109
# 1110          116       2110
# 1111          116       2111
# 1112          116       2112
#
# [1113 rows x 5 columns]

# %%
cols = df_main.columns.to_list()

# %%
cols = cols[-1:] + cols[:-1]

# %%
df_main = df_main[cols]

# %%
df_main
# Out:
#       Access_id access_date       Course  \
# 0          1000  06-10-2017   oracle-sql
# 1          1001  06-10-2017  informatica
# 2          1002  06-10-2017   oracle-sql
# 3          1003  11-10-2017  informatica
# 4          1004  11-10-2017  informatica
# ...         ...         ...          ...
# 1108       2108  10-05-2018        rdbms
# 1109       2109  02-05-2018        rdbms
# 1110       2110  02-05-2018        rdbms
# 1111       2111  15-05-2018        rdbms
# 1112       2112  15-05-2018        rdbms
#
#                                           Chapter  Employee_id
# 0              introduction-to-sql-oracle-sql-102          100
# 1             rank-transforamtion-informatica-405          100
# 2              introduction-to-sql-oracle-sql-102          100
# 3     introduction-to-informatica-informatica-392          100
# 4              working-with-files-informatica-394          100
# ...                                           ...          ...
# 1108        primary-key-foreign-key-file-rdbms-38          116
# 1109                          ef-codds-rules-file          116
# 1110                          ef-codds-rules-file          116
# 1111          what-is-a-transaction-file-rdbms-40          116
# 1112          what-is-a-transaction-file-rdbms-40          116
#
# [1113 rows x 5 columns]

# %%
file_path = "Access log.xlsx"
df_main.to_excel(file_path, index=False)

# %%
file_path = "Rejected logs.xlsx"
df_logrej.to_excel(file_path, index=False)

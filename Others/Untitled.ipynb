# %%
import pandas as pd
import re as re
df = pd.DataFrame({
    'company_code': ['Abcd','EFGF', 'zefsalf', 'sdfslew', 'zekfsdf'],
    'date_of_sale': ['12/05/2002','16/02/1999','05/09/1998','12/02/2022','15/09/1997'],
    'address': ['9910 Surrey <b>Avenue</b>','92 N. Bishop Avenue','9910 <br>Golden Star Avenue', '102 Dunbar <i></i>St.', '17 West Livingston Court']
})

# %%
df
# Out:
#   company_code date_of_sale                      address
# 0         Abcd   12/05/2002    9910 Surrey <b>Avenue</b>
# 1         EFGF   16/02/1999          92 N. Bishop Avenue
# 2      zefsalf   05/09/1998  9910 <br>Golden Star Avenue
# 3      sdfslew   12/02/2022        102 Dunbar <i></i>St.
# 4      zekfsdf   15/09/1997     17 West Livingston Court

# %%
df
# Out:
#   company_code date_of_sale                      address
# 0         Abcd   12/05/2002    9910 Surrey <b>Avenue</b>
# 1         EFGF   16/02/1999          92 N. Bishop Avenue
# 2      zefsalf   05/09/1998  9910 <br>Golden Star Avenue
# 3      sdfslew   12/02/2022        102 Dunbar <i></i>St.
# 4      zekfsdf   15/09/1997     17 West Livingston Court

# %%
import numpy as np

# %%
def remove_st(string):
    result = re.sub('<.*?>','',string)
    return result

df['without_t'] = df['address'].apply(lambda x:remove_st(x))
df
# Out:
#   company_code date_of_sale                      address  \
# 0         Abcd   12/05/2002    9910 Surrey <b>Avenue</b>
# 1         EFGF   16/02/1999          92 N. Bishop Avenue
# 2      zefsalf   05/09/1998  9910 <br>Golden Star Avenue
# 3      sdfslew   12/02/2022        102 Dunbar <i></i>St.
# 4      zekfsdf   15/09/1997     17 West Livingston Court
#
#                   without_t
# 0        9910 Surrey Avenue
# 1       92 N. Bishop Avenue
# 2   9910 Golden Star Avenue
# 3            102 Dunbar St.
# 4  17 West Livingston Court

# %%
nums = {'amount': [10, 250, 3000, 40000, 500000]}
df = pd.DataFrame(nums)
print(df)
df['amount'] = df['amount'].apply(lambda x: '{0:0>8}'.format(x))
print(df)
# Out:
#    amount
# 0      10
# 1     250
# 2    3000
# 3   40000
# 4  500000
#      amount
# 0  00000010
# 1  00000250
# 2  00003000
# 3  00040000
# 4  00500000

# %%
df = pd.DataFrame({
    'name_code': ['c001','c002','c022', 'c2002', 'c2222'],
    'date_of_birth ': ['12/05/2002','16/02/1999','25/09/1998','12/02/2022','15/09/1997'],
    'age': [18.5, 21.2, 22.5, 22, 23]
})

# %%
df['count'] = list(map(lambda x:x.count('2'),df['name_code']))
df
# Out:
#   name_code date_of_birth    age  count
# 0      c001     12/05/2002  18.5      0
# 1      c002     16/02/1999  21.2      1
# 2      c022     25/09/1998  22.5      2
# 3     c2002     12/02/2022  22.0      2
# 4     c2222     15/09/1997  23.0      4

# %%
df['find'] = list(map(lambda x:x.find('22'),df['name_code']))
df
# Out:
#   name_code date_of_birth    age  count  find
# 0      c001     12/05/2002  18.5      0    -1
# 1      c002     16/02/1999  21.2      1    -1
# 2      c022     25/09/1998  22.5      2     2
# 3     c2002     12/02/2022  22.0      2    -1
# 4     c2222     15/09/1997  23.0      4     1

# %%
df['len'] = df['name_code'].apply(len)
df
# Out:
#   name_code date_of_birth    age  count  find  len
# 0      c001     12/05/2002  18.5      0    -1    4
# 1      c002     16/02/1999  21.2      1    -1    4
# 2      c022     25/09/1998  22.5      2     2    4
# 3     c2002     12/02/2022  22.0      2    -1    5
# 4     c2222     15/09/1997  23.0      4     1    5

# %%
df = pd.DataFrame({
    'company_code': ['Abcd','EFGF', 'skfsalf', 'sdfslew', 'safsdf'],
    'date_of_sale': ['12/05/2002','16/02/1999','25/09/1998','12/02/2022','15/09/1997'],
    'sale_amount': [12348.5, 233331.2, 22.5, 2566552.0, 23.0]
})
df
# Out:
#   company_code date_of_sale  sale_amount
# 0         Abcd   12/05/2002      12348.5
# 1         EFGF   16/02/1999     233331.2
# 2      skfsalf   25/09/1998         22.5
# 3      sdfslew   12/02/2022    2566552.0
# 4       safsdf   15/09/1997         23.0

# %%
df['s'] = list(map(lambda x:x.startswith('A'),df['company_code']))
df
# Out:
#   company_code date_of_sale  sale_amount      s
# 0         Abcd   12/05/2002      12348.5   True
# 1         EFGF   16/02/1999     233331.2  False
# 2      skfsalf   25/09/1998         22.5  False
# 3      sdfslew   12/02/2022    2566552.0  False
# 4       safsdf   15/09/1997         23.0  False

# %%
df[df['company_code'].str.startswith('A')]
# Out:
#   company_code date_of_sale  sale_amount     s
# 0         Abcd   12/05/2002      12348.5  True

# %%
df = pd.DataFrame({
    'company_code': ['Abcd','EFGF', 'zefsalf', 'sdfslew', 'zekfsdf'],
    'date_of_sale': ['12/05/2002','16/02/1999','25/09/1998','12/02/2022','15/09/1997'],
    'sale_amount': [12348.5, 233331.2, 22.5, 2566552.0, 23.0]
})

# %%
df
# Out:
#   company_code date_of_sale  sale_amount
# 0         Abcd   12/05/2002      12348.5
# 1         EFGF   16/02/1999     233331.2
# 2      zefsalf   25/09/1998         22.5
# 3      sdfslew   12/02/2022    2566552.0
# 4      zekfsdf   15/09/1997         23.0

# %%
df['company_code'].str.swapcase()
# Out:
# 0       aBCD
# 1       efgf
# 2    ZEFSALF
# 3    SDFSLEW
# 4    ZEKFSDF
# Name: company_code, dtype: object

# %%
df = pd.DataFrame({
    'company_code': ['Abcd','EFGF', 'zefsalf', 'sdfslew', 'zekfsdf'],
    'date_of_sale': ['12/05/2002','16/02/1999','05/09/1998','12/02/2022','15/09/1997'],
    'address': ['9910 Surrey Avenue','92 N. Bishop Avenue','9910 Golden Star Avenue', '102 Dunbar St.', '17 West Livingston Court']
})
print("Original DataFrame:")
df
# Out:
# Original DataFrame:
#   company_code date_of_sale                   address
# 0         Abcd   12/05/2002        9910 Surrey Avenue
# 1         EFGF   16/02/1999       92 N. Bishop Avenue
# 2      zefsalf   05/09/1998   9910 Golden Star Avenue
# 3      sdfslew   12/02/2022            102 Dunbar St.
# 4      zekfsdf   15/09/1997  17 West Livingston Court

# %%
def pick_only_key_sentence(str1, word):
    result = re.findall(word, str1)
    return result
df['filter_sentence']=df['address'].apply(lambda x : pick_only_key_sentence(x,'Avenue'))
print("\nText with the word 'Avenue':")
df
# Out:
# Text with the word 'Avenue':
#   company_code date_of_sale                   address filter_sentence
# 0         Abcd   12/05/2002        9910 Surrey Avenue        [Avenue]
# 1         EFGF   16/02/1999       92 N. Bishop Avenue        [Avenue]
# 2      zefsalf   05/09/1998   9910 Golden Star Avenue        [Avenue]
# 3      sdfslew   12/02/2022            102 Dunbar St.              []
# 4      zekfsdf   15/09/1997  17 West Livingston Court              []

# %%
import datetime
from datetime import datetime
print("Datetime object for Jan 11 2012:")
print(datetime(2012, 1, 11))
print("\nSpecific date and time of 9:20 pm") 
print(datetime(2011, 1, 11, 21, 20))
print("\nLocal date and time:")
print(datetime.now())
print("\nA date without time: ")
print(datetime.date(datetime(2012, 5, 22)))
print("\nCurrent date:")
print(datetime.now().date())
print("\nTime from a datetime:")
print(datetime.time(datetime(2012, 12, 15, 18, 12)))
print("\nCurrent local time:") 
print(datetime.now().time())
# Out:
# Datetime object for Jan 11 2012:
# 2012-01-11 00:00:00
#
# Specific date and time of 9:20 pm
# 2011-01-11 21:20:00
#
# Local date and time:
# 2024-06-01 17:32:25.299396
#
# A date without time:
# 2012-05-22
#
# Current date:
# 2024-06-01
#
# Time from a datetime:
# 18:12:00
#
# Current local time:
# 17:32:25.299396

# %%
print(datetime.now().date())
# Out:
# 2024-06-01

# %%
print(datetime.date(datetime()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 print(datetime.date(datetime()))
#
# TypeError: function missing required argument 'year' (pos 1)

# %%
print(datetime.now())
# Out:
# 2024-06-01 17:33:07.184553

# %%
datetime.date()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 datetime.date()
#
# TypeError: unbound method datetime.date() needs an argument

# %%
pd.Timestamp('now')
# Out:
# Timestamp('2024-06-01 17:34:14.466068')

# %%
ddf = pd.read_csv('movie_metadata.csv')

# %%
df = ddf.iloc[:20]

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df[['movie_title','genres']]
# Out:
#                                           movie_title  \
# 0                                             Avatar
# 1           Pirates of the Caribbean: At World's End
# 2                                            Spectre
# 3                              The Dark Knight Rises
# 4   Star Wars: Episode VII - The Force Awakens    ...
# 5                                        John Carter
# 6                                       Spider-Man 3
# 7                                            Tangled
# 8                            Avengers: Age of Ultron
# 9             Harry Potter and the Half-Blood Prince
# 10                Batman v Superman: Dawn of Justice
# 11                                  Superman Returns
# 12                                 Quantum of Solace
# 13        Pirates of the Caribbean: Dead Man's Chest
# 14                                   The Lone Ranger
# 15                                      Man of Steel
# 16          The Chronicles of Narnia: Prince Caspian
# 17                                      The Avengers
# 18       Pirates of the Caribbean: On Stranger Tides
# 19                                    Men in Black 3
#
#                                                genres
# 0                     Action|Adventure|Fantasy|Sci-Fi
# 1                            Action|Adventure|Fantasy
# 2                           Action|Adventure|Thriller
# 3                                     Action|Thriller
# 4                                         Documentary
# 5                             Action|Adventure|Sci-Fi
# 6                            Action|Adventure|Romance
# 7   Adventure|Animation|Comedy|Family|Fantasy|Musi...
# 8                             Action|Adventure|Sci-Fi
# 9                    Adventure|Family|Fantasy|Mystery
# 10                            Action|Adventure|Sci-Fi
# 11                            Action|Adventure|Sci-Fi
# 12                                   Action|Adventure
# 13                           Action|Adventure|Fantasy
# 14                           Action|Adventure|Western
# 15                    Action|Adventure|Fantasy|Sci-Fi
# 16                    Action|Adventure|Family|Fantasy
# 17                            Action|Adventure|Sci-Fi
# 18                           Action|Adventure|Fantasy
# 19      Action|Adventure|Comedy|Family|Fantasy|Sci-Fi

# %%
df[df['movie_title'].str.contains('Grumpier Old Men')]
# Out:
# Empty DataFrame
# Columns: [color, director_name, num_critic_for_reviews, duration, director_facebook_likes, actor_3_facebook_likes, actor_2_name, actor_1_facebook_likes, gross, genres, actor_1_name, movie_title, num_voted_users, cast_total_facebook_likes, actor_3_name, facenumber_in_poster, plot_keywords, movie_imdb_link, num_user_for_reviews, language, country, content_rating, budget, title_year, actor_2_facebook_likes, imdb_score, aspect_ratio, movie_facebook_likes]
# Index: []
#
# [0 rows x 28 columns]

# %%
df.sort_values(['duration'],ascending=False).head(2)
# Out:
#     color  director_name  num_critic_for_reviews  duration  \
# 10  Color    Zack Snyder                   673.0     183.0
# 0   Color  James Cameron                   723.0     178.0
#
#     director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 10                      0.0                  2000.0      Lauren Cohan
# 0                       0.0                   855.0  Joel David Moore
#
#     actor_1_facebook_likes        gross                           genres  ...  \
# 10                 15000.0  330249062.0          Action|Adventure|Sci-Fi  ...
# 0                   1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
#
#    num_user_for_reviews language  country  content_rating       budget  \
# 10               3018.0  English      USA           PG-13  250000000.0
# 0                3054.0  English      USA           PG-13  237000000.0
#
#     title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 10      2016.0                 4000.0        6.9          2.35
# 0       2009.0                  936.0        7.9          1.78
#
#    movie_facebook_likes
# 10               197000
# 0                 33000
#
# [2 rows x 28 columns]

# %%
df[(df['duration']>=30) & (df['duration']<=360)]
# Out:
#     color      director_name  num_critic_for_reviews  duration  \
# 0   Color      James Cameron                   723.0     178.0
# 1   Color     Gore Verbinski                   302.0     169.0
# 2   Color         Sam Mendes                   602.0     148.0
# 3   Color  Christopher Nolan                   813.0     164.0
# 5   Color     Andrew Stanton                   462.0     132.0
# 6   Color          Sam Raimi                   392.0     156.0
# 7   Color       Nathan Greno                   324.0     100.0
# 8   Color        Joss Whedon                   635.0     141.0
# 9   Color        David Yates                   375.0     153.0
# 10  Color        Zack Snyder                   673.0     183.0
# 11  Color       Bryan Singer                   434.0     169.0
# 12  Color       Marc Forster                   403.0     106.0
# 13  Color     Gore Verbinski                   313.0     151.0
# 14  Color     Gore Verbinski                   450.0     150.0
# 15  Color        Zack Snyder                   733.0     143.0
# 16  Color     Andrew Adamson                   258.0     150.0
# 17  Color        Joss Whedon                   703.0     173.0
# 18  Color       Rob Marshall                   448.0     136.0
# 19  Color   Barry Sonnenfeld                   451.0     106.0
#
#     director_facebook_likes  actor_3_facebook_likes          actor_2_name  \
# 0                       0.0                   855.0      Joel David Moore
# 1                     563.0                  1000.0         Orlando Bloom
# 2                       0.0                   161.0          Rory Kinnear
# 3                   22000.0                 23000.0        Christian Bale
# 5                     475.0                   530.0       Samantha Morton
# 6                       0.0                  4000.0          James Franco
# 7                      15.0                   284.0          Donna Murphy
# 8                       0.0                 19000.0     Robert Downey Jr.
# 9                     282.0                 10000.0      Daniel Radcliffe
# 10                      0.0                  2000.0          Lauren Cohan
# 11                      0.0                   903.0         Marlon Brando
# 12                    395.0                   393.0       Mathieu Amalric
# 13                    563.0                  1000.0         Orlando Bloom
# 14                    563.0                  1000.0           Ruth Wilson
# 15                      0.0                   748.0    Christopher Meloni
# 16                     80.0                   201.0  Pierfrancesco Favino
# 17                      0.0                 19000.0     Robert Downey Jr.
# 18                    252.0                  1000.0           Sam Claflin
# 19                    188.0                   718.0     Michael Stuhlbarg
#
#     actor_1_facebook_likes        gross  \
# 0                   1000.0  760505847.0
# 1                  40000.0  309404152.0
# 2                  11000.0  200074175.0
# 3                  27000.0  448130642.0
# 5                    640.0   73058679.0
# 6                  24000.0  336530303.0
# 7                    799.0  200807262.0
# 8                  26000.0  458991599.0
# 9                  25000.0  301956980.0
# 10                 15000.0  330249062.0
# 11                 18000.0  200069408.0
# 12                   451.0  168368427.0
# 13                 40000.0  423032628.0
# 14                 40000.0   89289910.0
# 15                 15000.0  291021565.0
# 16                 22000.0  141614023.0
# 17                 26000.0  623279547.0
# 18                 40000.0  241063875.0
# 19                 10000.0  179020854.0
#
#                                                genres  ...  \
# 0                     Action|Adventure|Fantasy|Sci-Fi  ...
# 1                            Action|Adventure|Fantasy  ...
# 2                           Action|Adventure|Thriller  ...
# 3                                     Action|Thriller  ...
# 5                             Action|Adventure|Sci-Fi  ...
# 6                            Action|Adventure|Romance  ...
# 7   Adventure|Animation|Comedy|Family|Fantasy|Musi...  ...
# 8                             Action|Adventure|Sci-Fi  ...
# 9                    Adventure|Family|Fantasy|Mystery  ...
# 10                            Action|Adventure|Sci-Fi  ...
# 11                            Action|Adventure|Sci-Fi  ...
# 12                                   Action|Adventure  ...
# 13                           Action|Adventure|Fantasy  ...
# 14                           Action|Adventure|Western  ...
# 15                    Action|Adventure|Fantasy|Sci-Fi  ...
# 16                    Action|Adventure|Family|Fantasy  ...
# 17                            Action|Adventure|Sci-Fi  ...
# 18                           Action|Adventure|Fantasy  ...
# 19      Action|Adventure|Comedy|Family|Fantasy|Sci-Fi  ...
#
#    num_user_for_reviews language  country  content_rating       budget  \
# 0                3054.0  English      USA           PG-13  237000000.0
# 1                1238.0  English      USA           PG-13  300000000.0
# 2                 994.0  English       UK           PG-13  245000000.0
# 3                2701.0  English      USA           PG-13  250000000.0
# 5                 738.0  English      USA           PG-13  263700000.0
# 6                1902.0  English      USA           PG-13  258000000.0
# 7                 387.0  English      USA              PG  260000000.0
# 8                1117.0  English      USA           PG-13  250000000.0
# 9                 973.0  English       UK              PG  250000000.0
# 10               3018.0  English      USA           PG-13  250000000.0
# 11               2367.0  English      USA           PG-13  209000000.0
# 12               1243.0  English       UK           PG-13  200000000.0
# 13               1832.0  English      USA           PG-13  225000000.0
# 14                711.0  English      USA           PG-13  215000000.0
# 15               2536.0  English      USA           PG-13  225000000.0
# 16                438.0  English      USA              PG  225000000.0
# 17               1722.0  English      USA           PG-13  220000000.0
# 18                484.0  English      USA           PG-13  250000000.0
# 19                341.0  English      USA           PG-13  225000000.0
#
#     title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0       2009.0                  936.0        7.9          1.78
# 1       2007.0                 5000.0        7.1          2.35
# 2       2015.0                  393.0        6.8          2.35
# 3       2012.0                23000.0        8.5          2.35
# 5       2012.0                  632.0        6.6          2.35
# 6       2007.0                11000.0        6.2          2.35
# 7       2010.0                  553.0        7.8          1.85
# 8       2015.0                21000.0        7.5          2.35
# 9       2009.0                11000.0        7.5          2.35
# 10      2016.0                 4000.0        6.9          2.35
# 11      2006.0                10000.0        6.1          2.35
# 12      2008.0                  412.0        6.7          2.35
# 13      2006.0                 5000.0        7.3          2.35
# 14      2013.0                 2000.0        6.5          2.35
# 15      2013.0                 3000.0        7.2          2.35
# 16      2008.0                  216.0        6.6          2.35
# 17      2012.0                21000.0        8.1          1.85
# 18      2011.0                11000.0        6.7          2.35
# 19      2012.0                  816.0        6.8          1.85
#
#    movie_facebook_likes
# 0                 33000
# 1                     0
# 2                 85000
# 3                164000
# 5                 24000
# 6                     0
# 7                 29000
# 8                118000
# 9                 10000
# 10               197000
# 11                    0
# 12                    0
# 13                 5000
# 14                48000
# 15               118000
# 16                    0
# 17               123000
# 18                58000
# 19                40000
#
# [19 rows x 28 columns]

# %%
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,"--",70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,"?",12.43,2480.4,250.45, 3045.6],
'ord_date': ['?','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,"--",3002,3001,3001],
'salesman_id':[5002,5003,"?",5001,np.nan,5002,5001,"?",5003,5002,5003,"--"]})

# %%
df
# Out:
#    ord_no purch_amt    ord_date customer_id salesman_id
# 0   70001     150.5           ?        3002        5002
# 1     NaN    270.65  2012-09-10        3001        5003
# 2   70002     65.26         NaN        3001           ?
# 3   70004     110.5  2012-08-17        3003        5001
# 4     NaN     948.5  2012-09-10        3002         NaN
# 5   70005    2400.6  2012-07-27        3001        5002
# 6      --      5760  2012-09-10        3001        5001
# 7   70010         ?  2012-10-10        3004           ?
# 8   70003     12.43  2012-10-10          --        5003
# 9   70012    2480.4  2012-06-27        3002        5002
# 10    NaN    250.45  2012-08-17        3001        5003
# 11  70013    3045.6  2012-04-25        3001          --

# %%
df.replace({'?':np.nan,'--':np.nan},inplace=True)
df
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50         NaN       3002.0       5002.0
# 1       NaN     270.65  2012-09-10       3001.0       5003.0
# 2   70002.0      65.26         NaN       3001.0          NaN
# 3   70004.0     110.50  2012-08-17       3003.0       5001.0
# 4       NaN     948.50  2012-09-10       3002.0          NaN
# 5   70005.0    2400.60  2012-07-27       3001.0       5002.0
# 6       NaN    5760.00  2012-09-10       3001.0       5001.0
# 7   70010.0        NaN  2012-10-10       3004.0          NaN
# 8   70003.0      12.43  2012-10-10          NaN       5003.0
# 9   70012.0    2480.40  2012-06-27       3002.0       5002.0
# 10      NaN     250.45  2012-08-17       3001.0       5003.0
# 11  70013.0    3045.60  2012-04-25       3001.0          NaN

# %%
df.dropna(how='all',inplace=True)

# %%
df
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50         NaN       3002.0       5002.0
# 1       NaN     270.65  2012-09-10       3001.0       5003.0
# 2   70002.0      65.26         NaN       3001.0          NaN
# 3   70004.0     110.50  2012-08-17       3003.0       5001.0
# 4       NaN     948.50  2012-09-10       3002.0          NaN
# 5   70005.0    2400.60  2012-07-27       3001.0       5002.0
# 6       NaN    5760.00  2012-09-10       3001.0       5001.0
# 7   70010.0        NaN  2012-10-10       3004.0          NaN
# 8   70003.0      12.43  2012-10-10          NaN       5003.0
# 9   70012.0    2480.40  2012-06-27       3002.0       5002.0
# 10      NaN     250.45  2012-08-17       3001.0       5003.0
# 11  70013.0    3045.60  2012-04-25       3001.0          NaN

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[np.nan,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[np.nan,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': [np.nan,'2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[np.nan,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001]})

print("Original Orders DataFrame:")
print(df)
print("\nDrop the rows where all elements are missing:")
result = df.dropna(how='all')
print(result)
# Out:
# Original Orders DataFrame:
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3   70004.0     110.50  2012-08-17       3003.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11  70013.0    3045.60  2012-04-25       3001.0
#
# Drop the rows where all elements are missing:
#      ord_no  purch_amt    ord_date  customer_id
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3   70004.0     110.50  2012-08-17       3003.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11  70013.0    3045.60  2012-04-25       3001.0

# %%
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})

# %%
re = df['ord_no'].isnull().to_numpy().nonzero()
re
# Out:
# (array([ 1,  4,  6, 10], dtype=int64),)

# %%
df.isnull().sum()
# Out:
# ord_no         4
# purch_amt      3
# sale_amt       3
# ord_date       1
# customer_id    0
# salesman_id    3
# dtype: int64

# %%
df['ord_no'].value_counts()
# Out:
# ord_no
# 70001.0    1
# 70002.0    1
# 70004.0    1
# 70005.0    1
# 70010.0    1
# 70003.0    1
# 70012.0    1
# 70013.0    1
# Name: count, dtype: int64

# %%
df.value_counts()
# Out:
# ord_no   purch_amt  sale_amt  ord_date    customer_id  salesman_id
# 70001.0  150.50     10.50     2012-10-05  3002         5002.0         1
# 70012.0  250.45     25.45     2012-06-27  3002         5002.0         1
# Name: count, dtype: int64

# %%
def creating_gen(index):  
    months = ['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec']  
    yield months[index]  
    yield months[index+2]  
next_month = creating_gen(3)  
print(next(next_month), next(next_month))
# Out:
# apr jun

# %%
from collections import Counter

my_list = [1, 2, 3, 2, 1, 3, 1, 1, 2, 3, 4, 5,6]
counter = Counter(my_list)
most_common_elements = counter.most_common()

# %%
most_common_elements
# Out:
# [(1, 4), (2, 3), (3, 3), (4, 1), (5, 1), (6, 1)]

# %%
my_list = [1, 2, 3, 2, 1, 3, 1, 1, 2, 3, 4, 5]
unique_list = []
seen = set()

# %%
for i in my_list:
    if i not in seen:
        unique_list.append(i)
        seen.add(i)

# %%
unique_list
# Out:
# [1, 2, 3, 4, 5]

# %%
seen
# Out:
# {1, 2, 3, 4, 5}

# %%
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7, 8]

intersection = list(set(list1) & set(list2))
intersection
# Out:
# [4, 5]

# %%
list(set(list1) & set(list2))
# Out:
# [4, 5]

# %%
my_list = [{"name": "Alice", "age": 30}, {"name": "Bob", "age": 25}, {"name": "Charlie", "age": 35}]
my_list
# Out:
# [{'name': 'Alice', 'age': 30},
#  {'name': 'Bob', 'age': 25},
#  {'name': 'Charlie', 'age': 35}]

# %%
l = sorted(my_list,key = lambda x:x['age'])
l
# Out:
# [{'name': 'Bob', 'age': 25},
#  {'name': 'Alice', 'age': 30},
#  {'name': 'Charlie', 'age': 35}]

# %%
sorted_list = sorted(my_list, key=lambda x: x["age"])

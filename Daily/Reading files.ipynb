# %%
import pandas as pd
import glob
import os
import json
from datetime import datetime

# %%
file_paths = glob.glob(r'C:\Users\DELL\OneDrive\Desktop\AT files\Daily\raw\*.csv')

circuit_df = pd.DataFrame()
races_df = pd.DataFrame()

for file_path in file_paths:
    filename = os.path.basename(file_path).split('.')[0]
    df = pd.read_csv(file_path)
    if 'circuits' in filename.lower():
        circuit_df = df
    elif 'races' in filename.lower():
        races_df = df

# %%
directory = r'C:\Users\DELL\OneDrive\Desktop\AT files\Daily\raw'
file_paths = {
    'results': os.path.join(directory, 'results.json'),
    'pit_stops': os.path.join(directory, 'pit_stops.json'),
    'drivers': os.path.join(directory, 'drivers.json'),
    'constructors': os.path.join(directory, 'constructors.json')
}

# %%
results_df = pd.read_json(file_paths['results'],lines=True)
constructors_df = pd.read_json(file_paths['constructors'],lines=True)
pit_stops_df = pd.read_json(file_paths['pit_stops'])
drivers_df = pd.read_json(file_paths['drivers'],lines=True)

# %%
results_df 
constructors_df 
pit_stops_df
drivers_df
circuit_df
races_df
# Out:
#       raceId  year  round  circuitId                      name        date  \
# 0          1  2009      1          1     Australian Grand Prix  2009-03-29
# 1          2  2009      2          2      Malaysian Grand Prix  2009-04-05
# 2          3  2009      3         17        Chinese Grand Prix  2009-04-19
# 3          4  2009      4          3        Bahrain Grand Prix  2009-04-26
# 4          5  2009      5          4        Spanish Grand Prix  2009-05-10
# ...      ...   ...    ...        ...                       ...         ...
# 1053    1069  2021     18         69  United States Grand Prix  2021-10-24
# 1054    1070  2021     19         32    Mexico City Grand Prix  2021-10-31
# 1055    1071  2021     20         18      Brazilian Grand Prix  2021-11-07
# 1056    1072  2021     22         77  Saudi Arabian Grand Prix  2021-12-05
# 1057    1073  2021     23         24      Abu Dhabi Grand Prix  2021-12-12
#
#           time                                                url
# ...

# %%
dataframes = [results_df, constructors_df, pit_stops_df, drivers_df, circuit_df, races_df]
for df in dataframes:
    if 'url' in df.columns:
        df.drop(columns='url', inplace=True)

# %%
today_date = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
dataframes = [results_df, constructors_df, pit_stops_df, drivers_df, circuit_df, races_df]
for df in dataframes:
    df['created_date'] = today_date

# %%
column_mappings = {'raceId': 'race_id','circuitId':'circuit_id','driverId':'driver_id','raceID':'race_id','constructorId':'constructor_id','resultId':'result_id'}
dataframes = [results_df, constructors_df, pit_stops_df, drivers_df, circuit_df, races_df]

for df in dataframes:
    for current_col, new_col in column_mappings.items():
        if current_col in df.columns:
            df.rename(columns={current_col: new_col}, inplace=True)

# %%
# results_df.head(1)
# constructors_df.head(1)
# pit_stops_df.head(1)
# drivers_df.head(1)
# circuit_df.head(1)
# races_df.head(1)

# %%
races_df.head(1)
# Out:
#    race_id  year  round  circuit_id                   name        date  \
# 0        1  2009      1           1  Australian Grand Prix  2009-03-29
#
#        time         created_date
# 0  06:00:00  2024-07-18 11:58:11

# %%
circuit_df.head(1)
# Out:
#    circuit_id  circuit_ref                            name   location  \
# 0           1  albert_park  Albert Park Grand Prix Circuit  Melbourne
#
#      country      lat      lng  alt         created_date
# 0  Australia -37.8497  144.968   10  2024-07-18 11:58:11

# %%
drivers_df.head(1)
# Out:
#    driver_id driver_ref number code  \
# 0          1   hamilton     44  HAM
#
#                                            name         dob nationality  \
# 0  {'forename': 'Lewis', 'surname': 'Hamilton'}  1985-01-07     British
#
#           created_date
# 0  2024-07-18 11:58:11

# %%
pit_stops_df.head(1)
# Out:
#    race_id  driver_id  stop  lap      time duration  milliseconds  \
# 0      841        153     1    1  17:05:23   26.898         26898
#
#           created_date
# 0  2024-07-18 11:58:11

# %%
constructors_df.head(1)
# Out:
#    constructor_id constructor_ref     name nationality         created_date
# 0               1         mclaren  McLaren     British  2024-07-18 11:58:11

# %%
results_df.head(1)
# Out:
#    result_id  race_id  driver_id  constructor_id number  grid position  \
# 0          1       18          1               1     22     1        1
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId  \
# 0         39    2       1:27.452           218.3         1
#
#           created_date
# 0  2024-07-18 11:58:11

# %%
column_mappings = {'lat':'latitude','lng':'longitude','alt':'altitude'}
dataframes = [constructors_df, drivers_df, circuit_df]

for df in dataframes:
    for current_col, new_col in column_mappings.items():
        if current_col in df.columns:
            df.rename(columns={current_col: new_col}, inplace=True)

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('input.xlsx')

# %%
df.head(2)
# Out:
#   Encounter_Date Facility_Name Appointment_Provider_Name  \
# 0     2023-09-01     BARDSTOWN          SHOWN NP, JOHNNA
# 1     2023-09-01     BARDSTOWN          SHOWN NP, JOHNNA
#
#    Patient_Account_Number                    Visit     Category  \
# 0                 3254894  BARDSTOWN3254894912023P  Respiratory
# 1                 3254894  BARDSTOWN3254894912023P  Respiratory
#
#         Patient_Name Financial_Class Patient_Primary_Insurance_Name  \
# 0  MCCARTY, STELLA R          2-BCBS                    BCBS ANTHEM
# 1  MCCARTY, STELLA R          2-BCBS                    BCBS ANTHEM
#
#    Patient_Secondary_Insurance_Name  ... Procedure_Notes  Document_Section  \
# 0                               NaN  ...             NaN               NaN
# 1                               NaN  ...             NaN               NaN
#
#    GC_NGC  Status1  Status Arrival_Status POS INS_SelfPay Visit_Notes client
# 0     NGC      NaN  BILLED     Discharged NaN         NaN         NaN    NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Encounter_Date                    1000 non-null   datetime64[ns]
#  1   Facility_Name                     1000 non-null   object
#  2   Appointment_Provider_Name         1000 non-null   object
#  3   Patient_Account_Number            1000 non-null   int64
#  4   Visit                             1000 non-null   object
#  5   Category                          1000 non-null   object
#  6   Patient_Name                      1000 non-null   object
#  7   Financial_Class                   1000 non-null   object
#  8   Patient_Primary_Insurance_Name    1000 non-null   object
#  9   Patient_Secondary_Insurance_Name  0 non-null      float64
#  10  CPT_Code                          1000 non-null   object
# ...

# %%
df.shape
# Out:
# (1000, 40)

# %%
df.ndim
# Out:
# 2

# %%
df_null_percentage = ((df.isnull().sum()/len(df))*100).sort_values(ascending = False)
df_null_percentage
# Out:
# client                              100.0
# Visit_Notes                         100.0
# INS_SelfPay                         100.0
# POS                                 100.0
# Status1                             100.0
# Document_Section                    100.0
# Procedure_Notes                     100.0
# Encounter_Done_Status               100.0
# Patient_Secondary_Insurance_Name    100.0
# Modifier_1                          100.0
# Modifier_2                          100.0
# Modifier_3                          100.0
# ICD_Code_9                           99.6
# ICD_Code_8                           98.5
# ICD_Code_7                           97.9
# ICD_Code_6                           97.0
# ICD_Code_5                           93.6
# ICD_Code_4                           83.1
# ICD_Code_3                           64.0
# ICD_Code_2                           37.5
# ICD_Code_1                            2.5
# Financial_Class                       0.0
# ...

# %%
df.duplicated().sum() # for finding duplicates
# Out:
# 78

# %%
df.nunique().sort_values(ascending = False)
# Out:
# Visit                               356
# Patient_Account_Number              349
# Patient_Name                        349
# Arrived_Time                        281
# Departure_Time                      278
# Total_Time                          129
# ICD_Code_1                          123
# ICD_Code_2                           86
# CPT_Code                             55
# ICD_Code_3                           54
# Patient_Primary_Insurance_Name       46
# ICD_Code_4                           28
# Financial_Class                      18
# Appointment_Provider_Name            17
# Category                             15
# ICD_Code_5                           14
# Facility_Name                        11
# ICD_Code_6                            6
# Visit_type                            4
# Status                                4
# Arrival_Status                        4
# ICD_Code_7                            4
# ICD_Code_8                            2
# ...

# %%
df.columns
# Out:
# Index(['Encounter_Date', 'Facility_Name', 'Appointment_Provider_Name',
#        'Patient_Account_Number', 'Visit', 'Category', 'Patient_Name',
#        'Financial_Class', 'Patient_Primary_Insurance_Name',
#        'Patient_Secondary_Insurance_Name', 'CPT_Code', 'Modifier_1',
#        'Modifier_2', 'Modifier_3', 'Visit_type', 'ICD_Code_1', 'ICD_Code_2',
#        'ICD_Code_3', 'ICD_Code_4', 'ICD_Code_5', 'ICD_Code_6', 'ICD_Code_7',
#        'ICD_Code_8', 'ICD_Code_9', 'Units', 'Arrived_Time', 'Departure_Time',
#        'New_Patient', 'Encounter_Done_Status', 'Total_Time', 'Procedure_Notes',
#        'Document_Section', 'GC_NGC', 'Status1', 'Status', 'Arrival_Status',
#        'POS', 'INS_SelfPay', 'Visit_Notes', 'client'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Encounter_Date                      datetime64[ns]
# Facility_Name                               object
# Appointment_Provider_Name                   object
# Patient_Account_Number                       int64
# Visit                                       object
# Category                                    object
# Patient_Name                                object
# Financial_Class                             object
# Patient_Primary_Insurance_Name              object
# Patient_Secondary_Insurance_Name           float64
# CPT_Code                                    object
# Modifier_1                                 float64
# Modifier_2                                 float64
# Modifier_3                                 float64
# Visit_type                                  object
# ICD_Code_1                                  object
# ICD_Code_2                                  object
# ICD_Code_3                                  object
# ...

# %%
df['Total_Time'] = df['Total_Time'].astype('str')

# %%
df['Total_Time'] = df['Total_Time'].apply(lambda x : x.split('-')[-1])

# %%
df['Total_Time'] = pd.to_timedelta(df['Total_Time'])

# %%
df.dtypes
# Out:
# Encounter_Date                       datetime64[ns]
# Facility_Name                                object
# Appointment_Provider_Name                    object
# Patient_Account_Number                        int64
# Visit                                        object
# Category                                     object
# Patient_Name                                 object
# Financial_Class                              object
# Patient_Primary_Insurance_Name               object
# Patient_Secondary_Insurance_Name            float64
# CPT_Code                                     object
# Modifier_1                                  float64
# Modifier_2                                  float64
# Modifier_3                                  float64
# Visit_type                                   object
# ICD_Code_1                                   object
# ICD_Code_2                                   object
# ICD_Code_3                                   object
# ...

# %%
# Out:
#     Encounter_Date Facility_Name Appointment_Provider_Name  \
# 0       2023-09-01     BARDSTOWN          SHOWN NP, JOHNNA
# 1       2023-09-01     BARDSTOWN          SHOWN NP, JOHNNA
# 2       2023-09-01     BARDSTOWN          SHOWN NP, JOHNNA
# 3       2023-09-01     BARDSTOWN          SHOWN NP, JOHNNA
# 4       2023-09-01     BARDSTOWN          SHOWN NP, JOHNNA
# ..             ...           ...                       ...
# 995     2023-09-01    FCBARDSTKY       NIX NP, LYNN SHINAE
# 996     2023-09-01    FCBARDSTKY       NIX NP, LYNN SHINAE
# 997     2023-09-01    FCBARDSTKY       NIX NP, LYNN SHINAE
# 998     2023-09-01    FCBARDSTKY       NIX NP, LYNN SHINAE
# 999     2023-09-01    FCBARDSTKY       NIX NP, LYNN SHINAE
#
#      Patient_Account_Number                     Visit     Category  \
# 0                   3254894   BARDSTOWN3254894912023P  Respiratory
# 1                   3254894   BARDSTOWN3254894912023P  Respiratory
# ...
